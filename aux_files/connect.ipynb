# %%
from selenium import webdriver

import time

# %%
driver = webdriver.Chrome()
# ir a la pagina inicial
url = "https://www.edufacil.cl"
driver.get(url)
# Se hace el login
time.sleep(3)

# %%
# --- Configuración del navegador ---
chrome_options = Options()
chrome_options.add_argument("--start-maximized")  # abrir en pantalla completa
chrome_options.add_argument("--disable-blink-features=AutomationControlled")  # evita detección

service = Service(executable_path="C:/path/to/chromedriver.exe")  # ruta al chromedriver

# --- Crear instancia del navegador ---
driver = webdriver.Chrome(service=service, options=chrome_options)

# --- Abrir una página ---
url = "https://www.edufacil.cl"
driver.get(url)

# --- Esperar a que cargue ---
time.sleep(3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\selenium\webdriver\common\driver_finder.py:64, in DriverFinder._binary_paths(self)
#      63 if not Path(path).is_file():
# ---> 64     raise ValueError(f"The path is not a valid file: {path}")
#      65 self._paths["driver_path"] = path
#
# ValueError: The path is not a valid file: C:/path/to/chrome.exe
#
# The above exception was the direct cause of the following exception:
#
# NoSuchDriverException                     Traceback (most recent call last)
# Cell In[6], line 9
#       6 service = Service(executable_path="C:/path/to/chrome.exe")  # ruta al chromedriver
#       8 # --- Crear instancia del navegador ---
# ----> 9 driver = webdriver.Chrome(service=service, options=chrome_options)
#      11 # --- Abrir una página ---
#      12 url = "https://www.edufacil.cl"
#
# ...
